# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression , LinearRegression

# %%
from sklearn.model_selection import cross_val_score

# %%
# !pip install --upgrade scikit-learn mlxtend
# Out:
# Requirement already satisfied: scikit-learn in c:\users\parveen\anaconda3\lib\site-packages (1.5.2)
# Requirement already satisfied: mlxtend in c:\users\parveen\anaconda3\lib\site-packages (0.23.1)
# Collecting mlxtend
#   Obtaining dependency information for mlxtend from https://files.pythonhosted.org/packages/03/96/274a769f29be5adfee600edb97b97cc7817a86903f2477f8ca9c60445bc3/mlxtend-0.23.2-py3-none-any.whl.metadata
#   Downloading mlxtend-0.23.2-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\parveen\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\parveen\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\parveen\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\parveen\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\parveen\anaconda3\lib\site-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\parveen\anaconda3\lib\site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\parveen\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\parveen\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\parveen\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\parveen\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\parveen\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\parveen\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\parveen\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\parveen\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\parveen\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\parveen\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\parveen\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.2-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.4 MB 653.6 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.4 MB 1.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.4 MB 1.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.4 MB 2.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 4.8 MB/s eta 0:00:00
# Installing collected packages: mlxtend
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.23.1
#     Uninstalling mlxtend-0.23.1:
#       Successfully uninstalled mlxtend-0.23.1
# Successfully installed mlxtend-0.23.2

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
df = pd.DataFrame(iris.data , columns = iris.feature_names)

# %%
df['species'] = iris.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 5 columns]

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
lr = LogisticRegression()

# %%
sel = EFS(lr , max_features = 4 , scoring = 'accuracy' , cv =5)
sel
# Out:
# ExhaustiveFeatureSelector(estimator=LogisticRegression(), max_features=4)

# %%
model = sel.fit(df.iloc[:,:4],df['species'])
# Out:
# C:\Users\Parveen\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Features: 15/15

# %% [markdown]
# model.best_score_

# %%
model.best_score_
# Out:
# 0.9733333333333334

# %%
model.best_feature_names_
# Out:
# ('sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)')

# %%
model.subsets_
# Out:
# {0: {'feature_idx': (0,),
#   'cv_scores': array([0.66666667, 0.73333333, 0.76666667, 0.76666667, 0.83333333]),
#   'avg_score': 0.7533333333333333,
#   'feature_names': ('sepal length (cm)',)},
#  1: {'feature_idx': (1,),
#   'cv_scores': array([0.53333333, 0.56666667, 0.53333333, 0.56666667, 0.63333333]),
#   'avg_score': 0.5666666666666667,
#   'feature_names': ('sepal width (cm)',)},
#  2: {'feature_idx': (2,),
#   'cv_scores': array([0.93333333, 1.        , 0.9       , 0.93333333, 1.        ]),
#   'avg_score': 0.9533333333333334,
#   'feature_names': ('petal length (cm)',)},
#  3: {'feature_idx': (3,),
#   'cv_scores': array([1.        , 0.96666667, 0.9       , 0.93333333, 1.        ]),
#   'avg_score': 0.96,
#   'feature_names': ('petal width (cm)',)},
#  4: {'feature_idx': (0, 1),
#   'cv_scores': array([0.73333333, 0.83333333, 0.76666667, 0.86666667, 0.86666667]),
#   'avg_score': 0.8133333333333332,
#   'feature_names': ('sepal length (cm)', 'sepal width (cm)')},
#  5: {'feature_idx': (0, 2),
#   'cv_scores': array([0.93333333, 1.        , 0.9       , 0.93333333, 1.        ]),
#   'avg_score': 0.9533333333333334,
#   'feature_names': ('sepal length (cm)', 'petal length (cm)')},
#  6: {'feature_idx': (0, 3),
#   'cv_scores': array([0.93333333, 0.96666667, 0.93333333, 0.93333333, 1.        ]),
#   'avg_score': 0.9533333333333334,
#   'feature_names': ('sepal length (cm)', 'petal width (cm)')},
#  7: {'feature_idx': (1, 2),
#   'cv_scores': array([0.93333333, 1.        , 0.9       , 0.93333333, 1.        ]),
#   'avg_score': 0.9533333333333334,
#   'feature_names': ('sepal width (cm)', 'petal length (cm)')},
#  8: {'feature_idx': (1, 3),
#   'cv_scores': array([0.93333333, 0.96666667, 0.9       , 0.93333333, 0.96666667]),
#   'avg_score': 0.9400000000000001,
#   'feature_names': ('sepal width (cm)', 'petal width (cm)')},
#  9: {'feature_idx': (2, 3),
#   'cv_scores': array([0.96666667, 0.96666667, 0.93333333, 0.93333333, 1.        ]),
#   'avg_score': 0.96,
#   'feature_names': ('petal length (cm)', 'petal width (cm)')},
#  10: {'feature_idx': (0, 1, 2),
#   'cv_scores': array([0.93333333, 1.        , 0.9       , 0.93333333, 1.        ]),
#   'avg_score': 0.9533333333333334,
#   'feature_names': ('sepal length (cm)',
#    'sepal width (cm)',
#    'petal length (cm)')},
#  11: {'feature_idx': (0, 1, 3),
#   'cv_scores': array([0.9       , 0.96666667, 0.93333333, 0.93333333, 1.        ]),
#   'avg_score': 0.9466666666666667,
#   'feature_names': ('sepal length (cm)',
#    'sepal width (cm)',
#    'petal width (cm)')},
#  12: {'feature_idx': (0, 2, 3),
#   'cv_scores': array([0.96666667, 0.96666667, 0.93333333, 0.96666667, 1.        ]),
#   'avg_score': 0.9666666666666668,
#   'feature_names': ('sepal length (cm)',
#    'petal length (cm)',
#    'petal width (cm)')},
#  13: {'feature_idx': (1, 2, 3),
#   'cv_scores': array([0.96666667, 0.96666667, 0.93333333, 0.96666667, 1.        ]),
#   'avg_score': 0.9666666666666668,
#   'feature_names': ('sepal width (cm)',
#    'petal length (cm)',
#    'petal width (cm)')},
#  14: {'feature_idx': (0, 1, 2, 3),
#   'cv_scores': array([0.96666667, 1.        , 0.93333333, 0.96666667, 1.        ]),
#   'avg_score': 0.9733333333333334,
#   'feature_names': ('sepal length (cm)',
#    'sepal width (cm)',
#    'petal length (cm)',
#    'petal width (cm)')}}

# %%
metric_df = pd.DataFrame.from_dict(model.get_metric_dict()).T
metric_df
# Out:
#      feature_idx                                          cv_scores avg_score  \
# 0           (0,)  [0.6666666666666666, 0.7333333333333333, 0.766...  0.753333
# 1           (1,)  [0.5333333333333333, 0.5666666666666667, 0.533...  0.566667
# 2           (2,)  [0.9333333333333333, 1.0, 0.9, 0.9333333333333...  0.953333
# 3           (3,)  [1.0, 0.9666666666666667, 0.9, 0.9333333333333...      0.96
# 4         (0, 1)  [0.7333333333333333, 0.8333333333333334, 0.766...  0.813333
# 5         (0, 2)  [0.9333333333333333, 1.0, 0.9, 0.9333333333333...  0.953333
# 6         (0, 3)  [0.9333333333333333, 0.9666666666666667, 0.933...  0.953333
# 7         (1, 2)  [0.9333333333333333, 1.0, 0.9, 0.9333333333333...  0.953333
# 8         (1, 3)  [0.9333333333333333, 0.9666666666666667, 0.9, ...      0.94
# 9         (2, 3)  [0.9666666666666667, 0.9666666666666667, 0.933...      0.96
# 10     (0, 1, 2)  [0.9333333333333333, 1.0, 0.9, 0.9333333333333...  0.953333
# 11     (0, 1, 3)  [0.9, 0.9666666666666667, 0.9333333333333333, ...  0.946667
# 12     (0, 2, 3)  [0.9666666666666667, 0.9666666666666667, 0.933...  0.966667
# 13     (1, 2, 3)  [0.9666666666666667, 0.9666666666666667, 0.933...  0.966667
# 14  (0, 1, 2, 3)  [0.9666666666666667, 1.0, 0.9333333333333333, ...  0.973333
#
#                                         feature_names  ci_bound   std_dev  \
# 0                                (sepal length (cm),)  0.069612   0.05416
# 1                                 (sepal width (cm),)  0.046932  0.036515
# 2                                (petal length (cm),)  0.051412      0.04
# 3                                 (petal width (cm),)  0.049963  0.038873
# 4               (sepal length (cm), sepal width (cm))  0.069612   0.05416
# 5              (sepal length (cm), petal length (cm))  0.051412      0.04
# 6               (sepal length (cm), petal width (cm))  0.034274  0.026667
# 7               (sepal width (cm), petal length (cm))  0.051412      0.04
# 8                (sepal width (cm), petal width (cm))  0.032061  0.024944
# 9               (petal length (cm), petal width (cm))  0.032061  0.024944
# 10  (sepal length (cm), sepal width (cm), petal le...  0.051412      0.04
# 11  (sepal length (cm), sepal width (cm), petal wi...  0.043691  0.033993
# 12  (sepal length (cm), petal length (cm), petal w...  0.027096  0.021082
# 13  (sepal width (cm), petal length (cm), petal wi...  0.027096  0.021082
# 14  (sepal length (cm), sepal width (cm), petal le...  0.032061  0.024944
#
#      std_err
# 0    0.02708
# 1   0.018257
# 2       0.02
# 3   0.019437
# 4    0.02708
# 5       0.02
# 6   0.013333
# 7       0.02
# 8   0.012472
# 9   0.012472
# 10      0.02
# 11  0.016997
# 12  0.010541
# 13  0.010541
# 14  0.012472

# %%
import matplotlib.pyplot as plt

plt.plot([str(k) for k in metric_df['feature_names']],metric_df['avg_score'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Sequential Backward Elimination

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('HousingData.csv')

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
X = df.drop('MEDV' , axis = 1)
y = df['MEDV']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

print(X_train.shape)
# Out:
# (315, 13)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model = LinearRegression()

print("training",np.mean(cross_val_score(model, X_train, y_train, cv=52, scoring='r2')))
print("testing",np.mean(cross_val_score(model, X_test, y_test, cv=2, scoring='r2')))
# Out:
# training 0.58716935232208
# testing 0.7034535367982492

# %%
lr = LinearRegression()

# perform backward elimination
sfs = SFS(lr, k_features='best', forward=True, floating=False, scoring='r2',cv=5)

sfs.fit(X_train, y_train)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=(1, 13),
#                           scoring='r2')

# %%
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs


fig1 = plot_sfs(sfs.get_metric_dict(), kind='std_err',)

plt.title('Sequential Backward Elimination (w. StdErr)')
plt.grid()
plt.show()

# %%
X_train_sel = sfs.transform(X_train)
X_test_sel = sfs.transform(X_test)

model = LinearRegression()

print("training",np.mean(cross_val_score(model, X_train_sel, y_train, cv=5, scoring='r2')))
# Out:
# training 0.7138599653318101

# %% [markdown]
# ## Using Sklearn

# %%
from sklearn.feature_selection import SequentialFeatureSelector as SFS


sfs2 = SFS(model,
           n_features_to_select=5,
           direction='forward',
           scoring='r2',
           n_jobs=-1,
           cv=5)

sfs2 = sfs2.fit(X_train, y_train)

# %%
np.arange(X.shape[1])[sfs2.support_]
# Out:
# array([ 5,  7, 10, 11, 12])
